# %%
import pandas as pd

df = pd.read_csv("work_prodotti.csv", delimiter=";", encoding="latin-1")

# %%
df.head(5)
# Out:
#             FAMIGLIA MACRO_PRODOTTO GRUPPO_PRODOTTO                PRODOTTO  \
# 0  RISPARMIO GESTITO          FONDI    FONDI AGI IT  ALLIANZ REDDITO EURO L
# 1  RISPARMIO GESTITO          FONDI    FONDI AGI IT  ALLIANZ REDDITO EURO L
# 2  RISPARMIO GESTITO          FONDI    FONDI AGI IT  ALLIANZ REDDITO EURO L
# 3  RISPARMIO GESTITO          FONDI    FONDI AGI IT  ALLIANZ REDDITO EURO L
# 4  RISPARMIO GESTITO          FONDI    FONDI AGI IT  ALLIANZ REDDITO EURO L
#
#   COD_PROD SOTTO_PRODOTTO COD_SOTTOPROD      COD_ISIN ESPERIENZA_T  \
# 0    AT138            NaN           NaN  IT0000380045            M
# 1    AT138            NaN           NaN  IT0000380045            M
# 2    AT138            NaN           NaN  IT0000380045            M
# 3    AT138            NaN           NaN  IT0000380045            M
# 4    AT138            NaN           NaN  IT0000380045            M
#
#   CONOSCENZA_MIFID ISR_PRODOTTO                Tipologia Sottotipologia  \
# 0              Q.6    14,293713  Fondi e SICAV di Gruppo     AGI Italia
# 1              Q.6    14,293713  Fondi e SICAV di Gruppo     AGI Italia
# 2              Q.6    14,293713  Fondi e SICAV di Gruppo     AGI Italia
# 3              Q.6    14,293713  Fondi e SICAV di Gruppo     AGI Italia
# 4              Q.6    14,293713  Fondi e SICAV di Gruppo     AGI Italia
#
#     Bisogno data_riferimento CODICE_AA      PESO
# 0  Accumulo       30/11/2021    OBCPEU  0.334542
# 1  Accumulo       30/11/2021  OBGVEUBR  0.189901
# 2  Accumulo       30/11/2021  OBGVEUML  0.475557
# 3  Accumulo       30/11/2022    OBCPEU  0.334542
# 4  Accumulo       30/11/2022  OBGVEUBR  0.189901

# %%
df2 = df.groupby(by=["MACRO_PRODOTTO"])["Bisogno"].agg(["unique"])

# %%
df2.head(20)
# Out:
#                                                                        unique
# MACRO_PRODOTTO
# ALLIANZ (EX RBV)            [Protezione capitale, Protezione persona, LTC,...
# ALLIANZ GLOBAL LIFE                                                [Accumulo]
# ALLIANZ GLOBAL LIFE LIMITE                    [Accumulo, Protezione capitale]
# ALLIANZ LEBEN                                 [Protezione capitale, Accumulo]
# ALLIANZ LUX                                              [Multiramo (no PRV)]
# ALLIANZ S.P.A.              [Previdenza, Protezione capitale, Multiramo (n...
# ALLIANZ SUBALPINA           [Protezione capitale, Multiramo (no PRV), 0, I...
# CONTI CORRENTI                                                    [Liquidità]
# DARTA SAVING                                    [Accumulo, Liquidità, Income]
# DOSSIER TITOLI                                                            [0]
# FONDI                                           [Accumulo, Liquidità, Income]
# FONDI DI FONDI                                                     [Accumulo]
# GESTIONI                                                                  [0]
# GESTIONI INVESTITORI SGR                                        [0, Accumulo]
# SICAV                       [Accumulo, Income, Liquidità, Income - Liquidità]

# %%
from sqlalchemy import create_engine, text

schema_name = "mainapp"
engine = create_engine("postgresql://postgres:!vbPostgres@virtualb-rds-mainapp.clg6weaheijj.eu-south-1.rds.amazonaws.com:5432/postgres")

query="SELECT * FROM mainapp.test"

with engine.connect() as conn:
    result = conn.execute(text(query)).fetchall()

# %%
result
# Out:
# [(1, 'as'), (2, 'sd'), (3, 'df')]

# %%
query="select * from mainapp.test"

engine.execute(statement=query)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 3
#       1 query="select * from mainapp.test"
# ----> 3 engine.execute(statement=query)
#
# AttributeError: 'Engine' object has no attribute 'execute'
